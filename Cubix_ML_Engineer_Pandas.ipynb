# %% [markdown]
# <a href="https://colab.research.google.com/github/ZoltanV/cubix-ml-models/blob/main/Cubix_ML_Engineer_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install pandas

# %%
# https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf

# %%
import pandas as pd

# %%
# Example 0: Creating a pandas Series
pd.Series([1, 3, 5])
# Out:
# 0    1
# 1    3
# 2    5
# dtype: int64

# %%
### Pandas DataFrame Creation Examples

# Example 1: Creating a DataFrame from a dictionary of lists
# Keys become column names. Lists must be of the same length.
data_dict = {
    'A': [1, 2, 3],
    'B': [4, 5, 6],
    'C': [7, 8, 9]
}
df_from_dict = pd.DataFrame(data_dict)
print("DataFrame from dictionary:")
print(df_from_dict)
# Out:
# DataFrame from dictionary:
#    A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
pd.Series([1, 2, 3])
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
# Example 2: Creating a DataFrame from a list of dictionaries
# Each dictionary in the list represents a row. Keys become column names.
data_list_of_dicts = [
    {'A': 1, 'B': 4, 'C': 7},
    {'A': 2, 'B': 5, 'C': 8},
    {'A': 3, 'B': 6, 'C': 9}
]
df_from_list_of_dicts = pd.DataFrame(data_list_of_dicts)
print("\nDataFrame from list of dictionaries:")
print(df_from_list_of_dicts)
# Out:
# DataFrame from list of dictionaries:
#    A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
# Example 3: Creating a DataFrame using a MultiIndex
# A MultiIndex allows you to have multiple levels of indexes in rows or columns
index = pd.MultiIndex.from_tuples([('a', 1), ('a', 2), ('b', 1), ('b', 2)], names=['first', 'second'])
df_multi_index = pd.DataFrame({'A': [1, 2, 3, 4], 'B': [5, 6, 7, 8]}, index=index)
print("\nDataFrame with MultiIndex:")
print(df_multi_index)
# Out:
# DataFrame with MultiIndex:
#               A  B
# first second
# a     1       1  5
#       2       2  6
# b     1       3  7
#       2       4  8

# %%
# Example 4: Creating a DataFrame from a list of lists with column names specified
# Each inner list is a row. Column names are provided separately.
data_list_of_lists = [
    [1, 4, 7],
    [2, 5, 8],
    [3, 6, 9]
]
columns = ['A', 'B', 'C']
df_from_list_of_lists = pd.DataFrame(data_list_of_lists, columns=columns)
print("\nDataFrame from list of lists with column names:")
print(df_from_list_of_lists)
# Out:
# DataFrame from list of lists with column names:
#    A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
# Example 5: Creating an empty DataFrame with column names
# Useful when you need to create a DataFrame structure to be filled later.
empty_df = pd.DataFrame(columns=['A', 'B', 'C'])
print("\nEmpty DataFrame:")
print(empty_df)
# Out:
# Empty DataFrame:
# Empty DataFrame
# Columns: [A, B, C]
# Index: []

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
# Load a sample dataset from seaborn library
import seaborn as sns
df = sns.load_dataset('planets')

# %%
df.columns
# Out:
# Index(['method', 'number', 'orbital_period', 'mass', 'distance', 'year'], dtype='object')

# %%
df
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
df["distance"]
# Out:
# 0        77.40
# 1        56.95
# 2        19.84
# 3       110.62
# 4       119.47
#          ...
# 1030    172.00
# 1031    148.00
# 1032    174.00
# 1033    293.00
# 1034    260.00
# Name: distance, Length: 1035, dtype: float64

# %%
df.describe() # Descriptive statistics for each column
# Out:
#             number  orbital_period        mass     distance         year
# count  1035.000000      992.000000  513.000000   808.000000  1035.000000
# mean      1.785507     2002.917596    2.638161   264.069282  2009.070531
# std       1.240976    26014.728304    3.818617   733.116493     3.972567
# min       1.000000        0.090706    0.003600     1.350000  1989.000000
# 25%       1.000000        5.442540    0.229000    32.560000  2007.000000
# 50%       1.000000       39.979500    1.260000    55.250000  2010.000000
# 75%       2.000000      526.005000    3.040000   178.500000  2012.000000
# max       7.000000   730000.000000   25.000000  8500.000000  2014.000000

# %%
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
df.head(50)
# Out:
#                        method  number  orbital_period     mass  distance  year
# 0             Radial Velocity       1      269.300000   7.1000     77.40  2006
# 1             Radial Velocity       1      874.774000   2.2100     56.95  2008
# 2             Radial Velocity       1      763.000000   2.6000     19.84  2011
# 3             Radial Velocity       1      326.030000  19.4000    110.62  2007
# 4             Radial Velocity       1      516.220000  10.5000    119.47  2009
# 5             Radial Velocity       1      185.840000   4.8000     76.39  2008
# 6             Radial Velocity       1     1773.400000   4.6400     18.15  2002
# 7             Radial Velocity       1      798.500000      NaN     21.41  1996
# 8             Radial Velocity       1      993.300000  10.3000     73.10  2008
# 9             Radial Velocity       2      452.800000   1.9900     74.79  2010
# 10            Radial Velocity       2      883.000000   0.8600     74.79  2010
# ...

# %%
df.tail()
# Out:
#        method  number  orbital_period  mass  distance  year
# 1030  Transit       1        3.941507   NaN     172.0  2006
# 1031  Transit       1        2.615864   NaN     148.0  2007
# 1032  Transit       1        3.191524   NaN     174.0  2007
# 1033  Transit       1        4.125083   NaN     293.0  2008
# 1034  Transit       1        4.187757   NaN     260.0  2008

# %%
# Selecting a subset of the dataset for demonstration
df_subset = df[['mass', 'distance', 'year']]
df_subset
# Out:
#        mass  distance  year
# 0      7.10     77.40  2006
# 1      2.21     56.95  2008
# 2      2.60     19.84  2011
# 3     19.40    110.62  2007
# 4     10.50    119.47  2009
# ...     ...       ...   ...
# 1030    NaN    172.00  2006
# 1031    NaN    148.00  2007
# 1032    NaN    174.00  2007
# 1033    NaN    293.00  2008
# 1034    NaN    260.00  2008
#
# [1035 rows x 3 columns]

# %%
# Wide to Long
long_df = pd.melt(df_subset, id_vars=['year'], value_vars=['mass', 'distance'])
long_df
# Out:
#       year  variable   value
# 0     2006      mass    7.10
# 1     2008      mass    2.21
# 2     2011      mass    2.60
# 3     2007      mass   19.40
# 4     2009      mass   10.50
# ...    ...       ...     ...
# 2065  2006  distance  172.00
# 2066  2007  distance  148.00
# 2067  2007  distance  174.00
# 2068  2008  distance  293.00
# 2069  2008  distance  260.00
#
# [2070 rows x 3 columns]

# %%
# Long to Wide (the opposite of the last one)
wide_df = long_df.pivot_table(index=['year'], columns='variable', values='value', aggfunc='mean')
wide_df
# Out:
# variable    distance       mass
# year
# 1989       40.570000  11.680000
# 1995       15.360000   0.472000
# 1996       15.866667   1.979400
# 1997       17.430000   1.040000
# 1998       26.302000   2.687120
# 1999       30.947333   3.236643
# 2000       30.752500   3.633014
# 2001       36.531667   3.430909
# 2002       44.396129   3.937290
# 2003       43.085417   3.660955
# 2004      184.777826   1.454267
# 2005       46.484324   2.003897
# 2006      660.228929   1.799800
# 2007      162.656000   3.702094
# 2008       98.680312   3.424339
# 2009       82.056747   3.628568
# 2010      256.796344   1.289610
# 2011      319.015032   1.209084
# 2012      563.286154   3.658596
# 2013      529.767746   2.203400
# 2014      359.836667   1.068000

# %%
df_subset.head()
# Out:
#     mass  distance  year
# 0   7.10     77.40  2006
# 1   2.21     56.95  2008
# 2   2.60     19.84  2011
# 3  19.40    110.62  2007
# 4  10.50    119.47  2009

# %%
# Transpose
transposed_df = df_subset.head().T
transposed_df
# Out:
#                0        1        2        3        4
# mass         7.1     2.21     2.60    19.40    10.50
# distance    77.4    56.95    19.84   110.62   119.47
# year      2006.0  2008.00  2011.00  2007.00  2009.00

# %%
df
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
df.iloc[10:]
# Out:
#                method  number  orbital_period  mass  distance  year
# 10    Radial Velocity       2      883.000000  0.86     74.79  2010
# 11    Radial Velocity       1      335.100000  9.88     39.43  2009
# 12    Radial Velocity       1      479.100000  3.88     97.28  2008
# 13    Radial Velocity       3     1078.000000  2.53     14.08  1996
# 14    Radial Velocity       3     2391.000000  0.54     14.08  2001
# ...               ...     ...             ...   ...       ...   ...
# 1030          Transit       1        3.941507   NaN    172.00  2006
# 1031          Transit       1        2.615864   NaN    148.00  2007
# 1032          Transit       1        3.191524   NaN    174.00  2007
# 1033          Transit       1        4.125083   NaN    293.00  2008
# 1034          Transit       1        4.187757   NaN    260.00  2008
#
# [1025 rows x 6 columns]

# %%
# Concat and filtering: with particular index
pd.concat([df.iloc[100:], df.iloc[:100]])
# Out:
#               method  number  orbital_period  mass  distance  year
# 100          Transit       1       95.273800   NaN     460.0  2009
# 101          Transit       1       13.240600   NaN     345.0  2010
# 102          Transit       1        2.994330   NaN     560.0  2010
# 103          Transit       1        2.828042   NaN    1150.0  2010
# 104          Transit       1        4.035190   NaN    1060.0  2010
# ..               ...     ...             ...   ...       ...   ...
# 95           Transit       1        4.037896   NaN       NaN  2009
# 96           Transit       1        8.886593   NaN       NaN  2009
# 97           Transit       2        0.853585   NaN     150.0  2009
# 98   Radial Velocity       2        3.698000   NaN     150.0  2009
# 99           Transit       1        6.212290   NaN     380.0  2010
#
# [1035 rows x 6 columns]

# %%
# reset index
pd.concat([df.iloc[100:], df.iloc[:100]]).reset_index()
# Out:
#       index           method  number  orbital_period  mass  distance  year
# 0       100          Transit       1       95.273800   NaN     460.0  2009
# 1       101          Transit       1       13.240600   NaN     345.0  2010
# 2       102          Transit       1        2.994330   NaN     560.0  2010
# 3       103          Transit       1        2.828042   NaN    1150.0  2010
# 4       104          Transit       1        4.035190   NaN    1060.0  2010
# ...     ...              ...     ...             ...   ...       ...   ...
# 1030     95          Transit       1        4.037896   NaN       NaN  2009
# 1031     96          Transit       1        8.886593   NaN       NaN  2009
# 1032     97          Transit       2        0.853585   NaN     150.0  2009
# 1033     98  Radial Velocity       2        3.698000   NaN     150.0  2009
# 1034     99          Transit       1        6.212290   NaN     380.0  2010
#
# [1035 rows x 7 columns]

# %%
# reset index - dropping indexes from columns
concated = pd.concat([df.iloc[100:], df.iloc[:100]]).reset_index(drop=True)
concated
# Out:
#                method  number  orbital_period  mass  distance  year
# 0             Transit       1       95.273800   NaN     460.0  2009
# 1             Transit       1       13.240600   NaN     345.0  2010
# 2             Transit       1        2.994330   NaN     560.0  2010
# 3             Transit       1        2.828042   NaN    1150.0  2010
# 4             Transit       1        4.035190   NaN    1060.0  2010
# ...               ...     ...             ...   ...       ...   ...
# 1030          Transit       1        4.037896   NaN       NaN  2009
# 1031          Transit       1        8.886593   NaN       NaN  2009
# 1032          Transit       2        0.853585   NaN     150.0  2009
# 1033  Radial Velocity       2        3.698000   NaN     150.0  2009
# 1034          Transit       1        6.212290   NaN     380.0  2010
#
# [1035 rows x 6 columns]

# %%
# Subsets - filtering: with particular logic
concated.loc[concated["distance"] < 20]
# Out:
#                method  number  orbital_period   mass  distance  year
# 14    Radial Velocity       1        15.76491  3.910     10.91  1999
# 15    Radial Velocity       3         8.63100  0.035     14.97  2013
# 16    Radial Velocity       3        25.60000  0.024     14.97  2013
# 17    Radial Velocity       3       603.00000  0.079     14.97  2013
# 18    Radial Velocity       1      2288.00000  0.820     12.12  2009
# ...               ...     ...             ...    ...       ...   ...
# 1000  Radial Velocity       4       241.25800  1.981     13.47  1999
# 1001  Radial Velocity       4      1276.46000  4.132     13.47  1999
# 1002  Radial Velocity       4      3848.86000  1.059     13.47  2010
# 1003          Imaging       1    318280.00000    NaN      7.69  2008
# 1007          Imaging       1      4639.15000    NaN     12.21  2009
#
# [117 rows x 6 columns]

# %%
# Subsets - filtering: More than one logics are in brackets
concated.loc[(concated["distance"] < 20) &
            (concated["year"] == 2010)]
# Out:
#                method  number  orbital_period   mass  distance  year
# 37    Radial Velocity       3      1050.30000  4.950     16.13  2010
# 45    Radial Velocity       4       124.26000  0.046      4.70  2010
# 49    Radial Velocity       1         2.64561  0.022     19.80  2010
# 103   Radial Velocity       1       533.00000  6.100      7.01  2010
# 304   Radial Velocity       2      4970.00000  0.360     17.99  2010
# 313   Radial Velocity       1       122.10000  0.050      9.24  2010
# 336   Radial Velocity       2       263.30000  0.270     15.71  2010
# 337   Radial Velocity       2      1657.00000  0.710     15.71  2010
# 437        Astrometry       1      1016.00000    NaN     14.98  2010
# 531   Radial Velocity       1        41.39700  0.298     11.03  2010
# 535           Imaging       1             NaN    NaN     11.43  2010
# 1002  Radial Velocity       4      3848.86000  1.059     13.47  2010

# %%
df.iloc[50:100]
# Out:
#              method  number  orbital_period     mass  distance  year
# 50  Radial Velocity       1      594.900000   7.6000     47.53  2006
# 51  Radial Velocity       1      428.500000   8.7800     38.52  2009
# 52  Radial Velocity       1      903.300000   1.8500     13.79  2003
# 53  Radial Velocity       1     1251.000000      NaN     31.12  2007
# 54          Imaging       1             NaN      NaN     52.03  2012
# 55  Radial Velocity       1      136.750000   2.8000     62.66  2007
# 56  Radial Velocity       2      530.320000      NaN     46.84  2012
# 57  Radial Velocity       2     3186.000000      NaN     46.84  2012
# 58  Radial Velocity       1      277.020000   1.7000     80.64  2013
# 59  Radial Velocity       1      187.830000      NaN     84.03  2012
# 60  Radial Velocity       1     1630.000000      NaN     56.31  2012
# 61  Radial Velocity       1       39.845000   1.0400     17.43  1997
# 62  Radial Velocity       1        3.313500   3.9000     15.60  1996
# ...

# %%
# Sort values
df.sort_values("distance").head(50)
# Out:
#                method  number  orbital_period     mass  distance  year
# 46    Radial Velocity       1         3.23570  0.00360      1.35  2012
# 48    Radial Velocity       1      2502.00000  1.55000      3.22  2000
# 136   Radial Velocity       1         4.69380  0.03500      4.54  2007
# 144   Radial Velocity       4         1.93778  0.02100      4.70  2005
# 142   Radial Velocity       4        61.11660  2.27560      4.70  1998
# 143   Radial Velocity       4        30.08810  0.71420      4.70  2000
# 145   Radial Velocity       4       124.26000  0.04600      4.70  2010
# 140   Radial Velocity       1      3416.00000  0.64000      4.94  2008
# 264   Radial Velocity       3        90.30900  0.01510      6.06  2011
# 262   Radial Velocity       3        18.31500  0.00850      6.06  2011
# 263   Radial Velocity       3        40.11400  0.00755      6.06  2011
# 126   Radial Velocity       4        12.92920  0.01700      6.27  2005
# ...

# %%
print(df["distance"].median())
print(df["distance"].mean())
print(df["distance"].min())
print(df["distance"].max())
print(df["distance"].sum())
# Out:
# 55.25
# 264.06928217821786
# 1.35
# 8500.0
# 213367.98000000004

# %%
df_subset.groupby(by="year").mean()
# Out:
#            mass    distance
# year
# 1989  11.680000   40.570000
# 1992        NaN         NaN
# 1994        NaN         NaN
# 1995   0.472000   15.360000
# 1996   1.979400   15.866667
# 1997   1.040000   17.430000
# 1998   2.687120   26.302000
# 1999   3.236643   30.947333
# 2000   3.633014   30.752500
# 2001   3.430909   36.531667
# 2002   3.937290   44.396129
# 2003   3.660955   43.085417
# 2004   1.454267  184.777826
# 2005   2.003897   46.484324
# 2006   1.799800  660.228929
# 2007   3.702094  162.656000
# 2008   3.424339   98.680312
# 2009   3.628568   82.056747
# 2010   1.289610  256.796344
# 2011   1.209084  319.015032
# 2012   3.658596  563.286154
# 2013   2.203400  529.767746
# 2014   1.068000  359.836667

# %%
df_subset.sort_values(by="year")["year"].reset_index(drop=True).plot()
# Out:
# <Axes: >

# %%
df["year"].hist(bins=20)
# Out:
# <Axes: >

# %%
df["year"].plot.hist(bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.drop(columns=["year"])
# Out:
#                method  number  orbital_period   mass  distance
# 0     Radial Velocity       1      269.300000   7.10     77.40
# 1     Radial Velocity       1      874.774000   2.21     56.95
# 2     Radial Velocity       1      763.000000   2.60     19.84
# 3     Radial Velocity       1      326.030000  19.40    110.62
# 4     Radial Velocity       1      516.220000  10.50    119.47
# ...               ...     ...             ...    ...       ...
# 1030          Transit       1        3.941507    NaN    172.00
# 1031          Transit       1        2.615864    NaN    148.00
# 1032          Transit       1        3.191524    NaN    174.00
# 1033          Transit       1        4.125083    NaN    293.00
# 1034          Transit       1        4.187757    NaN    260.00
#
# [1035 rows x 5 columns]

# %%
df.drop(index=[0, 1])
# Out:
#                method  number  orbital_period   mass  distance  year
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# 5     Radial Velocity       1      185.840000   4.80     76.39  2008
# 6     Radial Velocity       1     1773.400000   4.64     18.15  2002
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1033 rows x 6 columns]
